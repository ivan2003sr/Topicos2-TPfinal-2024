# %% [markdown]
# # Generando un dataset de entrenamiento

# %%
import rdflib
from utils.csv2pronto.src import converter
import os
import pandas as pd
import numpy as np

# %%
owl = rdflib.Namespace("http://www.w3.org/2002/07/owl#")
sameAs = owl.sameAs
ns2 = rdflib.Namespace("http://rdfs.org/sioc/ns#")

# %%
def create_graph_with_sameAs(line):
    query = """
        SELECT ?space WHERE {
        # ?space a ns2:Space .
        }
        """
    g = rdflib.Graph()
    if line == '':
        return g
    for idx in line.split():
        g += converter.create_graph_real_estate(df.loc[int(idx)])
    g.print()
    result = g.query(query)
    spaces = [row.space for row in result]
    for space1, space2 in zip(spaces, spaces[1:]):
        g.add((space1, sameAs, space2))
    return g

# %%
df = pd.read_csv('dataset/raw.csv.gz', dialect='excel', keep_default_na=False, dtype=str, index_col=0)

# %%
datasets = []
for file in os.scandir('dataset'):
    if file.name.startswith('entrega_tis'):
        datasets.append(file)
datasets
# Out:
# [<DirEntry 'entrega_tis_grupo_17.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_08.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_11.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_13.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_18.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_02.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_09.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_06.csv.gz'>,
#  <DirEntry 'entrega_tis_grupo_07.csv.gz'>]

# %%
g = create_graph_with_sameAs('1401 383705 610889')
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix ns1: <https://raw.githubusercontent.com/jwackito/csv2pronto/main/ontology/pronto.owl#> .
# @prefix ns2: <http://purl.org/goodrelations/v1#> .
# @prefix ns3: <https://w3id.org/rec/core/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns1:real_estate_site1_13355519 a ns3:RealEstate ;
#     ns3:includes ns1:space_site1_13355519 .
#
# ns1:real_estate_site2_A1452032990 a ns3:RealEstate ;
#     ns3:includes ns1:space_site2_A1452032990 .
#
# ns1:real_estate_site3_52123269 a ns3:RealEstate ;
#     ns3:includes ns1:space_site3_52123269 .
#
# ns1:district_Buenos%20Aires_Avellaneda a ns3:Region ;
#     rdfs:label "Avellaneda"^^xsd:string ;
#     ns3:locatedIn ns1:province_Buenos%20Aires .
#
# ns1:feature_Acceso%20a%20internet_False a ns1:Feature ;
#     rdfs:label "Acceso a internet: False"^^xsd:string ;
#     dc:title "Acceso a internet"^^xsd:string .
#
# ns1:feature_Agua%20cloaca_True a ns1:Feature ;
#     rdfs:label "Agua cloaca: True"^^xsd:string ;
#     dc:title "Agua cloaca"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Agua%20corriente_True a ns1:Feature ;
#     rdfs:label "Agua corriente: True"^^xsd:string ;
#     dc:title "Agua corriente"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Aire%20acondicionado_False a ns1:Feature ;
#     rdfs:label "Aire acondicionado: False"^^xsd:string ;
#     dc:title "Aire acondicionado"^^xsd:string .
#
# ns1:feature_Alarma_False a ns1:Feature ;
#     rdfs:label "Alarma: False"^^xsd:string ;
#     dc:title "Alarma"^^xsd:string .
#
# ns1:feature_Altillo_False a ns1:Feature ;
#     rdfs:label "Altillo: False"^^xsd:string ;
#     dc:title "Altillo"^^xsd:string .
#
# ns1:feature_Ambientes_4 a ns1:Feature ;
#     rdfs:label "Ambientes: 4"^^xsd:string ;
#     dc:title "Ambientes"^^xsd:string ;
#     ns1:has_value "4"^^xsd:string .
#
# ns1:feature_Antig%C3%BCedad_15%20a%C3%B1os a ns1:Feature ;
#     rdfs:label "Antigüedad: 15 años"^^xsd:string ;
#     dc:title "Antigüedad"^^xsd:string ;
#     ns1:has_value "15 años"^^xsd:string .
#
# ns1:feature_Antiguedad_15 a ns1:Feature ;
#     rdfs:label "Antiguedad: 15"^^xsd:string ;
#     dc:title "Antiguedad"^^xsd:string ;
#     ns1:has_value "15"^^xsd:string .
#
# ns1:feature_Apto%20cr%C3%A9dito_False a ns1:Feature ;
#     rdfs:label "Apto crédito: False"^^xsd:string ;
#     dc:title "Apto crédito"^^xsd:string .
#
# ns1:feature_Apto%20profesional_False a ns1:Feature ;
#     rdfs:label "Apto profesional: False"^^xsd:string ;
#     dc:title "Apto profesional"^^xsd:string .
#
# ns1:feature_Ba%C3%B1o_True a ns1:Feature ;
#     rdfs:label "Baño: True"^^xsd:string ;
#     dc:title "Baño"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Ba%C3%B1os_1 a ns1:Feature ;
#     rdfs:label "Baños: 1"^^xsd:string ;
#     dc:title "Baños"^^xsd:string ;
#     ns1:has_value "1"^^xsd:string .
#
# ns1:feature_Balc%C3%B3n_False a ns1:Feature ;
#     rdfs:label "Balcón: False"^^xsd:string ;
#     dc:title "Balcón"^^xsd:string .
#
# ns1:feature_Calefacci%C3%B3n_False a ns1:Feature ;
#     rdfs:label "Calefacción: False"^^xsd:string ;
#     dc:title "Calefacción"^^xsd:string .
#
# ns1:feature_Cant.%20Ambientes_4 a ns1:Feature ;
#     rdfs:label "Cant. Ambientes: 4"^^xsd:string ;
#     dc:title "Cant. Ambientes"^^xsd:string ;
#     ns1:has_value "4"^^xsd:string .
#
# ns1:feature_Cant.%20Ba%C3%B1os_1 a ns1:Feature ;
#     rdfs:label "Cant. Baños: 1"^^xsd:string ;
#     dc:title "Cant. Baños"^^xsd:string ;
#     ns1:has_value "1"^^xsd:string .
#
# ns1:feature_Cant.%20Cocheras_1 a ns1:Feature ;
#     rdfs:label "Cant. Cocheras: 1"^^xsd:string ;
#     dc:title "Cant. Cocheras"^^xsd:string ;
#     ns1:has_value "1"^^xsd:string .
#
# ns1:feature_Cant.%20Dormitorios_3 a ns1:Feature ;
#     rdfs:label "Cant. Dormitorios: 3"^^xsd:string ;
#     dc:title "Cant. Dormitorios"^^xsd:string ;
#     ns1:has_value "3"^^xsd:string .
#
# ns1:feature_Cantidad%20de%20pisos_0 a ns1:Feature ;
#     rdfs:label "Cantidad de pisos: 0"^^xsd:string ;
#     dc:title "Cantidad de pisos"^^xsd:string ;
#     ns1:has_value "0"^^xsd:string .
#
# ns1:feature_Cantidad%20plantas_1 a ns1:Feature ;
#     rdfs:label "Cantidad plantas: 1"^^xsd:string ;
#     dc:title "Cantidad plantas"^^xsd:string ;
#     ns1:has_value "1"^^xsd:string .
#
# ns1:feature_Cobertura%20cochera_Cubierta a ns1:Feature ;
#     rdfs:label "Cobertura cochera: Cubierta"^^xsd:string ;
#     dc:title "Cobertura cochera"^^xsd:string ;
#     ns1:has_value "Cubierta"^^xsd:string .
#
# ns1:feature_Cochera_True a ns1:Feature ;
#     rdfs:label "Cochera: True"^^xsd:string ;
#     dc:title "Cochera"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Cocheras_1 a ns1:Feature ;
#     rdfs:label "Cocheras: 1"^^xsd:string ;
#     dc:title "Cocheras"^^xsd:string ;
#     ns1:has_value "1"^^xsd:string .
#
# ns1:feature_Comedor%20de%20diario_True a ns1:Feature ;
#     rdfs:label "Comedor de diario: True"^^xsd:string ;
#     dc:title "Comedor de diario"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Comedor%20diario_True a ns1:Feature ;
#     rdfs:label "Comedor diario: True"^^xsd:string ;
#     dc:title "Comedor diario"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Con%20lavadero_True a ns1:Feature ;
#     rdfs:label "Con lavadero: True"^^xsd:string ;
#     dc:title "Con lavadero"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Con%20tour%20virtual_False a ns1:Feature ;
#     rdfs:label "Con tour virtual: False"^^xsd:string ;
#     dc:title "Con tour virtual"^^xsd:string .
#
# ns1:feature_Condici%C3%B3n%20del%20%C3%ADtem_Usado a ns1:Feature ;
#     rdfs:label "Condición del ítem: Usado"^^xsd:string ;
#     dc:title "Condición del ítem"^^xsd:string ;
#     ns1:has_value "Usado"^^xsd:string .
#
# ns1:feature_Dependencia%20de%20servicio_False a ns1:Feature ;
#     rdfs:label "Dependencia de servicio: False"^^xsd:string ;
#     dc:title "Dependencia de servicio"^^xsd:string .
#
# ns1:feature_Dormitorio_True a ns1:Feature ;
#     rdfs:label "Dormitorio: True"^^xsd:string ;
#     dc:title "Dormitorio"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Dormitorios_3 a ns1:Feature ;
#     rdfs:label "Dormitorios: 3"^^xsd:string ;
#     dc:title "Dormitorios"^^xsd:string ;
#     ns1:has_value "3"^^xsd:string .
#
# ns1:feature_Electricidad_True a ns1:Feature ;
#     rdfs:label "Electricidad: True"^^xsd:string ;
#     dc:title "Electricidad"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Estudio_False a ns1:Feature ;
#     rdfs:label "Estudio: False"^^xsd:string ;
#     dc:title "Estudio"^^xsd:string .
#
# ns1:feature_Expensas_0%20ARS a ns1:Feature ;
#     rdfs:label "Expensas: 0 ARS"^^xsd:string ;
#     dc:title "Expensas"^^xsd:string ;
#     ns1:has_value "0 ARS"^^xsd:string .
#
# ns1:feature_Frente%20del%20terreno%20%28mts%29_0 a ns1:Feature ;
#     rdfs:label "Frente del terreno (mts): 0"^^xsd:string ;
#     dc:title "Frente del terreno (mts)"^^xsd:string ;
#     ns1:has_value "0"^^xsd:string .
#
# ns1:feature_Gimnasio_False a ns1:Feature ;
#     rdfs:label "Gimnasio: False"^^xsd:string ;
#     dc:title "Gimnasio"^^xsd:string .
#
# ns1:feature_Inmueble_Casa a ns1:Feature ;
#     rdfs:label "Inmueble: Casa"^^xsd:string ;
#     dc:title "Inmueble"^^xsd:string ;
#     ns1:has_value "Casa"^^xsd:string .
#
# ns1:feature_Jacuzzi_False a ns1:Feature ;
#     rdfs:label "Jacuzzi: False"^^xsd:string ;
#     dc:title "Jacuzzi"^^xsd:string .
#
# ns1:feature_L%C3%ADnea%20telef%C3%B3nica_False a ns1:Feature ;
#     rdfs:label "Línea telefónica: False"^^xsd:string ;
#     dc:title "Línea telefónica"^^xsd:string .
#
# ns1:feature_Largo%20del%20terreno%20%28mts%29_0 a ns1:Feature ;
#     rdfs:label "Largo del terreno (mts): 0"^^xsd:string ;
#     dc:title "Largo del terreno (mts)"^^xsd:string ;
#     ns1:has_value "0"^^xsd:string .
#
# ns1:feature_Operaci%C3%B3n_Venta a ns1:Feature ;
#     rdfs:label "Operación: Venta"^^xsd:string ;
#     dc:title "Operación"^^xsd:string ;
#     ns1:has_value "Venta"^^xsd:string .
#
# ns1:feature_Parrilla_False a ns1:Feature ;
#     rdfs:label "Parrilla: False"^^xsd:string ;
#     dc:title "Parrilla"^^xsd:string .
#
# ns1:feature_Patio_False a ns1:Feature ;
#     rdfs:label "Patio: False"^^xsd:string ;
#     dc:title "Patio"^^xsd:string .
#
# ns1:feature_Permite%20mascotas_True a ns1:Feature ;
#     rdfs:label "Permite mascotas: True"^^xsd:string ;
#     dc:title "Permite mascotas"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Pileta_False a ns1:Feature ;
#     rdfs:label "Pileta: False"^^xsd:string ;
#     dc:title "Pileta"^^xsd:string .
#
# ns1:feature_Playroom_False a ns1:Feature ;
#     rdfs:label "Playroom: False"^^xsd:string ;
#     dc:title "Playroom"^^xsd:string .
#
# ns1:feature_Precio_USD%20120.000 a ns1:Feature ;
#     rdfs:label "Precio: USD 120.000"^^xsd:string ;
#     dc:title "Precio"^^xsd:string ;
#     ns1:has_value "USD 120.000"^^xsd:string .
#
# ns1:feature_Seguridad_False a ns1:Feature ;
#     rdfs:label "Seguridad: False"^^xsd:string ;
#     dc:title "Seguridad"^^xsd:string .
#
# ns1:feature_Subtipo%20de%20operaci%C3%B3n_Propiedad%20individual a ns1:Feature ;
#     rdfs:label "Subtipo de operación: Propiedad individual"^^xsd:string ;
#     dc:title "Subtipo de operación"^^xsd:string ;
#     ns1:has_value "Propiedad individual"^^xsd:string .
#
# ns1:feature_Sup.%20Cubierta_154%20m2 a ns1:Feature ;
#     rdfs:label "Sup. Cubierta: 154 m2"^^xsd:string ;
#     dc:title "Sup. Cubierta"^^xsd:string ;
#     ns1:has_value "154 m2"^^xsd:string .
#
# ns1:feature_Superficie%20Semicubierta%20%28m%C2%B2%29_0 a ns1:Feature ;
#     rdfs:label "Superficie Semicubierta (m²): 0"^^xsd:string ;
#     dc:title "Superficie Semicubierta (m²)"^^xsd:string ;
#     ns1:has_value "0"^^xsd:string .
#
# ns1:feature_Superficie%20cubierta_154%20m%C2%B2 a ns1:Feature ;
#     rdfs:label "Superficie cubierta: 154 m²"^^xsd:string ;
#     dc:title "Superficie cubierta"^^xsd:string ;
#     ns1:has_value "154 m²"^^xsd:string .
#
# ns1:feature_Superficie%20total_154%20m%C2%B2 a ns1:Feature ;
#     rdfs:label "Superficie total: 154 m²"^^xsd:string ;
#     dc:title "Superficie total"^^xsd:string ;
#     ns1:has_value "154 m²"^^xsd:string .
#
# ns1:feature_TV%20por%20cable_False a ns1:Feature ;
#     rdfs:label "TV por cable: False"^^xsd:string ;
#     dc:title "TV por cable"^^xsd:string .
#
# ns1:feature_Tipo%20de%20operaci%C3%B3n_Venta a ns1:Feature ;
#     rdfs:label "Tipo de operación: Venta"^^xsd:string ;
#     dc:title "Tipo de operación"^^xsd:string ;
#     ns1:has_value "Venta"^^xsd:string .
#
# ns1:feature_Toilette_False a ns1:Feature ;
#     rdfs:label "Toilette: False"^^xsd:string ;
#     dc:title "Toilette"^^xsd:string .
#
# ns1:feature_Vestidor_False a ns1:Feature ;
#     rdfs:label "Vestidor: False"^^xsd:string ;
#     dc:title "Vestidor"^^xsd:string .
#
# ns1:neibourhood_Bs.As.%20G.B.A.%20Sur_Avellaneda_Sarand%C3%AD a ns3:Region ;
#     rdfs:label "Sarandí"^^xsd:string ;
#     ns3:locatedIn ns1:district_Bs.As.%20G.B.A.%20Sur_Avellaneda,
#         ns1:province_Bs.As.%20G.B.A.%20Sur .
#
# ns1:neibourhood_GBA%20Sur_Avellaneda_Sarandi a ns3:Region ;
#     rdfs:label "Sarandi"^^xsd:string ;
#     ns3:locatedIn ns1:district_GBA%20Sur_Avellaneda,
#         ns1:province_GBA%20Sur .
#
# ns1:space_site1_13355519 a ns3:Space ;
#     ns1:hasSizeSpecification [ a ns1:SizeSpecification ;
#             ns2:hasUnitOfMeasurement "m²"^^xsd:string ;
#             ns2:hasValue "154.0"^^xsd:float ;
#             ns1:size_type "covered"^^xsd:string ] ;
#     ns1:has_feature ns1:feature_Agua%20cloaca_True,
#         ns1:feature_Agua%20corriente_True,
#         ns1:feature_Antiguedad_15,
#         ns1:feature_Ba%C3%B1o_True,
#         ns1:feature_Cant.%20Ambientes_4,
#         ns1:feature_Cant.%20Ba%C3%B1os_1,
#         ns1:feature_Cant.%20Cocheras_1,
#         ns1:feature_Cant.%20Dormitorios_3,
#         ns1:feature_Cochera_True,
#         ns1:feature_Comedor%20diario_True,
#         ns1:feature_Comedor_True,
#         ns1:feature_Dormitorio_True,
#         ns1:feature_Electricidad_True,
#         ns1:feature_Gas%20natural_True,
#         ns1:feature_Lavadero_True,
#         ns1:feature_Living%20comedor_True,
#         ns1:feature_Living_True,
#         ns1:feature_Precio_USD%20120.000,
#         ns1:feature_Sup.%20Cubierta_154%20m2,
#         ns1:feature_Terraza_True,
#         ns1:feature_Tipo%20de%20operaci%C3%B3n_Venta ;
#     ns1:property_type "Casa"^^xsd:string ;
#     schema:latitude -3.468835e+01 ;
#     schema:longitude -5.834586e+01 ;
#     schema:yearBuilt 2009 ;
#     ns3:hasPart ns1:space_site1_13355519_bath_0,
#         ns1:space_site1_13355519_bed_0,
#         ns1:space_site1_13355519_bed_1,
#         ns1:space_site1_13355519_bed_2 ;
#     ns3:locatedIn ns1:district_Buenos%20Aires_Avellaneda,
#         ns1:province_Buenos%20Aires .
#
# ns1:space_site1_13355519_bath_0 a <https://w3id.org/rec/building/Bathroom> .
#
# ns1:space_site1_13355519_bed_0 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site1_13355519_bed_1 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site1_13355519_bed_2 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site2_A1452032990 a ns3:Space ;
#     ns1:hasSizeSpecification [ a ns1:SizeSpecification ;
#             ns2:hasUnitOfMeasurement "m²"^^xsd:string ;
#             ns2:hasValue "154.0"^^xsd:float ;
#             ns1:size_type "covered"^^xsd:string ],
#         [ a ns1:SizeSpecification ;
#             ns2:hasUnitOfMeasurement "m²"^^xsd:string ;
#             ns2:hasValue "154.0"^^xsd:float ;
#             ns1:size_type "total"^^xsd:string ] ;
#     ns1:has_amount_of_rooms 4 ;
#     ns1:has_feature ns1:feature_Acceso%20a%20internet_False,
#         ns1:feature_Aire%20acondicionado_False,
#         ns1:feature_Alarma_False,
#         ns1:feature_Altillo_False,
#         ns1:feature_Ambientes_4,
#         ns1:feature_Antig%C3%BCedad_15%20a%C3%B1os,
#         ns1:feature_Apto%20cr%C3%A9dito_False,
#         ns1:feature_Apto%20profesional_False,
#         ns1:feature_Ba%C3%B1os_1,
#         ns1:feature_Balc%C3%B3n_False,
#         ns1:feature_Calefacci%C3%B3n_False,
#         ns1:feature_Cantidad%20de%20pisos_0,
#         ns1:feature_Cocheras_1,
#         ns1:feature_Cocina_True,
#         ns1:feature_Comedor_True,
#         ns1:feature_Con%20lavadero_True,
#         ns1:feature_Con%20tour%20virtual_False,
#         ns1:feature_Condici%C3%B3n%20del%20%C3%ADtem_Usado,
#         ns1:feature_Dependencia%20de%20servicio_False,
#         ns1:feature_Dormitorios_3,
#         ns1:feature_Estudio_False,
#         ns1:feature_Expensas_0%20ARS,
#         ns1:feature_Gas%20natural_True,
#         ns1:feature_Gimnasio_False,
#         ns1:feature_Inmueble_Casa,
#         ns1:feature_Jacuzzi_False,
#         ns1:feature_Jard%C3%ADn_True,
#         ns1:feature_L%C3%ADnea%20telef%C3%B3nica_False,
#         ns1:feature_Living_True,
#         ns1:feature_Operaci%C3%B3n_Venta,
#         ns1:feature_Parrilla_False,
#         ns1:feature_Patio_False,
#         ns1:feature_Pileta_False,
#         ns1:feature_Playroom_False,
#         ns1:feature_Seguridad_False,
#         ns1:feature_Subtipo%20de%20operaci%C3%B3n_Propiedad%20individual,
#         ns1:feature_Superficie%20cubierta_154%20m%C2%B2,
#         ns1:feature_Superficie%20total_154%20m%C2%B2,
#         ns1:feature_TV%20por%20cable_False,
#         ns1:feature_Terraza_True,
#         ns1:feature_Toilette_False,
#         ns1:feature_Vestidor_False ;
#     ns1:property_type "Casa"^^xsd:string ;
#     schema:address "General Molina 392, Sarandí ¡casa de Cuatro Ambientes en Venta!"^^xsd:string ;
#     schema:latitude -3.468835e+01 ;
#     schema:longitude -5.834586e+01 ;
#     schema:yearBuilt 2009 ;
#     ns3:hasPart ns1:space_site2_A1452032990_bath_0,
#         ns1:space_site2_A1452032990_bed_0,
#         ns1:space_site2_A1452032990_bed_1,
#         ns1:space_site2_A1452032990_bed_2,
#         ns1:space_site2_A1452032990_garage_0 ;
#     ns3:locatedIn ns1:district_Bs.As.%20G.B.A.%20Sur_Avellaneda,
#         ns1:neibourhood_Bs.As.%20G.B.A.%20Sur_Avellaneda_Sarand%C3%AD,
#         ns1:province_Bs.As.%20G.B.A.%20Sur .
#
# ns1:space_site2_A1452032990_bath_0 a <https://w3id.org/rec/building/Bathroom> .
#
# ns1:space_site2_A1452032990_bed_0 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site2_A1452032990_bed_1 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site2_A1452032990_bed_2 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site2_A1452032990_garage_0 a <https://w3id.org/rec/building/Garage> .
#
# ns1:space_site3_52123269 a ns3:Space ;
#     ns1:hasSizeSpecification [ a ns1:SizeSpecification ;
#             ns2:hasUnitOfMeasurement "m²"^^xsd:string ;
#             ns2:hasValue "154.0"^^xsd:float ;
#             ns1:size_type "covered"^^xsd:string ],
#         [ a ns1:SizeSpecification ;
#             ns2:hasUnitOfMeasurement "m²"^^xsd:string ;
#             ns2:hasValue "154.0"^^xsd:float ;
#             ns1:size_type "total"^^xsd:string ] ;
#     ns1:has_amount_of_rooms 4 ;
#     ns1:has_feature ns1:feature_Cantidad%20plantas_1,
#         ns1:feature_Cobertura%20cochera_Cubierta,
#         ns1:feature_Cocina_True,
#         ns1:feature_Comedor%20de%20diario_True,
#         ns1:feature_Comedor_True,
#         ns1:feature_Frente%20del%20terreno%20%28mts%29_0,
#         ns1:feature_Jard%C3%ADn_True,
#         ns1:feature_Largo%20del%20terreno%20%28mts%29_0,
#         ns1:feature_Lavadero_True,
#         ns1:feature_Living%20comedor_True,
#         ns1:feature_Living_True,
#         ns1:feature_Permite%20mascotas_True,
#         ns1:feature_Superficie%20Semicubierta%20%28m%C2%B2%29_0,
#         ns1:feature_Terraza_True ;
#     ns1:property_type "Casa"^^xsd:string ;
#     schema:address "General Molina 392, Sarandí ¡casa de Cuatro Ambientes en Venta!"^^xsd:string ;
#     schema:latitude -3.468835e+01 ;
#     schema:longitude -5.834586e+01 ;
#     schema:yearBuilt 2009 ;
#     ns3:hasPart ns1:space_site3_52123269_bath_0,
#         ns1:space_site3_52123269_bed_0,
#         ns1:space_site3_52123269_bed_1,
#         ns1:space_site3_52123269_bed_2,
#         ns1:space_site3_52123269_garage_0 ;
#     ns3:locatedIn ns1:district_GBA%20Sur_Avellaneda,
#         ns1:neibourhood_GBA%20Sur_Avellaneda_Sarandi,
#         ns1:province_GBA%20Sur .
#
# ns1:space_site3_52123269_bath_0 a <https://w3id.org/rec/building/Bathroom> .
#
# ns1:space_site3_52123269_bed_0 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site3_52123269_bed_1 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site3_52123269_bed_2 a <https://w3id.org/rec/building/Bedroom> .
#
# ns1:space_site3_52123269_garage_0 a <https://w3id.org/rec/building/Garage> .
#
# ns1:district_Bs.As.%20G.B.A.%20Sur_Avellaneda a ns3:Region ;
#     rdfs:label "Avellaneda"^^xsd:string ;
#     ns3:locatedIn ns1:province_Bs.As.%20G.B.A.%20Sur .
#
# ns1:district_GBA%20Sur_Avellaneda a ns3:Region ;
#     rdfs:label "Avellaneda"^^xsd:string ;
#     ns3:locatedIn ns1:province_GBA%20Sur .
#
# ns1:feature_Cocina_True a ns1:Feature ;
#     rdfs:label "Cocina: True"^^xsd:string ;
#     dc:title "Cocina"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Gas%20natural_True a ns1:Feature ;
#     rdfs:label "Gas natural: True"^^xsd:string ;
#     dc:title "Gas natural"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Jard%C3%ADn_True a ns1:Feature ;
#     rdfs:label "Jardín: True"^^xsd:string ;
#     dc:title "Jardín"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Lavadero_True a ns1:Feature ;
#     rdfs:label "Lavadero: True"^^xsd:string ;
#     dc:title "Lavadero"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Living%20comedor_True a ns1:Feature ;
#     rdfs:label "Living comedor: True"^^xsd:string ;
#     dc:title "Living comedor"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:province_Buenos%20Aires a ns3:Region ;
#     rdfs:label "Buenos Aires"^^xsd:string .
#
# ns1:feature_Comedor_True a ns1:Feature ;
#     rdfs:label "Comedor: True"^^xsd:string ;
#     dc:title "Comedor"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Living_True a ns1:Feature ;
#     rdfs:label "Living: True"^^xsd:string ;
#     dc:title "Living"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:feature_Terraza_True a ns1:Feature ;
#     rdfs:label "Terraza: True"^^xsd:string ;
#     dc:title "Terraza"^^xsd:string ;
#     ns1:has_value "true"^^xsd:string .
#
# ns1:province_Bs.As.%20G.B.A.%20Sur a ns3:Region ;
#     rdfs:label "Bs.As. G.B.A. Sur"^^xsd:string .
#
# ns1:province_GBA%20Sur a ns3:Region ;
#     rdfs:label "GBA Sur"^^xsd:string .

# %%
g.print()

# %%
full_graph = rdflib.Graph()
for dataset in list(datasets)[0]:
    idxs = pd.read_csv(dataset.path,index_col=0)
    for duplicated in idxs.dup_curated.values:
        g = create_graph_with_sameAs(duplicated)
        full_graph += g

# %%
full_graph

# %%
for s, p, o in list(g.triples((None, None, None))):
    if str(p).count('sameAs') > 0:
        print(f'{s.replace("\t", "_")}\t{p.replace("\t", "_")}\t{o.replace("\t", "_")}\n')
